# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap

# %%
serial_csv = pd.read_csv("serialResults.csv")
serial_csv
# Out:
#        centroid  danceability    energy  loudness  speechiness  \
# 0             0      0.422473  0.524885  0.566087     0.024694
# 1             0      0.436559  0.324836  0.687303     0.240767
# 2             0      0.653267  0.478873  0.713217     0.022636
# 3             0      0.775707  0.492877  0.704232     0.031951
# 4             0      0.807130  0.523884  0.730092     0.023178
# ...         ...           ...       ...       ...          ...
# 42300         3      0.659768  0.882972  0.763950     0.086971
# 42301         3      0.674938  0.759942  0.662375     0.052529
# 42302         3      0.650016  0.904977  0.698480     0.022636
# 42303         3      0.522158  0.862967  0.754773     0.029676
# 42304         3      0.536244  0.723933  0.719107     0.008665
#
#            acousticness  instrumental  liveness   valence     tempo
# 0              0.137651      0.742164  0.116955  0.268544  0.382152
# 1              0.116396      0.734075  0.100583  0.020633  0.820703
# 2              0.061942      0.412538  0.111839  0.085938  0.641640
# 3              0.072570      0.592518  0.114908  0.020221  0.949065
# 4              0.044938      0.721941  0.096490  0.140617  0.394577
# ...                 ...           ...       ...       ...       ...
# 42300          0.315789      0.582406  0.060370  0.345920  0.567184
# 42301          0.029351      0.400404  0.030492  0.295368  0.566728
# 42302          0.012145      0.759353  0.332856  0.712163  0.573074
# 42303          0.004412      0.457027  0.078175  0.404725  0.566753
# 42304          0.026720      0.845298  0.343088  0.640978  0.566851
#
# [42305 rows x 10 columns]

# %%
# axes instance
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(serial_csv.energy, serial_csv.tempo, serial_csv.loudness, c=serial_csv.centroid, marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('energy')
ax.set_ylabel('tempo')
ax.set_zlabel('loudness')

# legend
plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)

# save
#plt.savefig("serial_results")

# %%
openmp_csv = pd.read_csv("OpenMPResults.csv")
openmp_csv
# Out:
#        centroid  danceability    energy  loudness  speechiness  \
# 0             0      0.590421  0.629910  0.616573     0.010398
# 1             0      0.599090  0.804953  0.685084     0.071808
# 2             0      0.828800  0.549891  0.597069     0.119463
# 3             0      0.731282  0.926982  0.701411     0.042348
# 4             0      0.664102  0.724933  0.635557     0.068342
# ...         ...           ...       ...       ...          ...
# 42300        11      0.580670  0.421860  0.547678     0.536445
# 42301        11      0.806046  0.544889  0.730831     0.055020
# 42302        11      0.382382  0.241816  0.609670     0.104300
# 42303        11      0.725864  0.368847  0.648541     0.049930
# 42304        11      0.560082  0.271823  0.758663     0.029676
#
#            acousticness  instrumental  liveness   valence     tempo
# 0              0.009837      0.889788  0.084109  0.018467  0.382226
# 1              0.000427      0.823054  0.102630  0.029093  0.443776
# 2              0.051011      0.902932  0.094444  0.154029  0.431584
# 3              0.000949      0.905966  0.094444  0.000929  0.450109
# 4              0.004078      0.811931  0.122071  0.201486  0.714853
# ...                 ...           ...       ...       ...       ...
# 42300          0.212550      0.000000  0.074900  0.561539  0.458894
# 42301          0.396760      0.000000  0.143559  0.232436  0.240514
# 42302          0.556680      0.000340  0.362529  0.266481  0.444792
# 42303          0.338056      0.000000  0.117978  0.223151  0.505394
# 42304          0.885627      0.000000  0.122071  0.345920  0.911017
#
# [42305 rows x 10 columns]

# %%
# axes instance
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(openmp_csv.energy, openmp_csv.tempo, openmp_csv.loudness, c=openmp_csv.centroid, marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('energy')
ax.set_ylabel('tempo')
ax.set_zlabel('loudness')

# legend
plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)

# save
#plt.savefig("serial_results")
