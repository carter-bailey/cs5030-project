# %%
import seaborn as sns
import pandas as pd

# %%
csv = pd.read_csv("results.csv")
csv
# Out:
#        centroid  danceability  energy  loudness  speechiness  \
# 0             0         0.719   0.493    -7.230       0.0794
# 1             0         0.736   0.932    -3.726       0.2710
# 2             0         0.814   0.575    -9.635       0.0635
# 3             0         0.602   0.578    -5.610       0.0283
# 4             0         0.876   0.768    -6.606       0.2010
# ...         ...           ...     ...       ...          ...
# 42300         7         0.568   0.981    -4.619       0.0604
# 42301         7         0.535   0.812    -3.825       0.0450
# 42302         7         0.526   0.974    -4.657       0.0545
# 42303         7         0.535   0.812    -3.825       0.0450
# 42304         7         0.228   0.735    -3.250       0.0400
#
#            acousticness  instrumental  liveness  valence    tempo
# 0               0.40100      0.000000    0.1180    0.124  115.080
# 1               0.14600      0.002500    0.1820    0.180  124.514
# ...

# %%
sns.scatterplot(x=csv.energy, y=csv.loudness, hue=csv.centroid)
# Out:
# <AxesSubplot:xlabel='energy', ylabel='loudness'>
