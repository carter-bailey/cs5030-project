# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap

# %%
serial_csv = pd.read_csv("results/serialResults.csv")
serial_csv
# Out:
#        centroid  danceability   energy  loudness  speechiness  acousticness  \
# 0             0       0.70853  0.49288   0.71571     0.061410      0.405870
# 1             0       0.71069  0.56789   0.60436     0.423810      0.045748
# 2             0       0.70744  0.66792   0.79975     0.123800      0.025707
# 3             0       0.68144  0.71093   0.76242     0.214770      0.040181
# 4             0       0.76812  0.75094   0.84679     0.189860      0.062145
# ...         ...           ...      ...       ...          ...           ...
# 42300         7       0.41705  0.96999   0.79291     0.035850      0.076517
# 42301         7       0.25994  0.92398   0.79178     0.196360      0.002509
# 42302         7       0.39647  0.79995   0.78351     0.055128      0.009220
# 42303         7       0.32712  0.87197   0.76688     0.027943      0.005738
# 42304         7       0.47340  0.99100   0.79507     0.235350      0.005606
#
#        instrumental  liveness   valence    tempo
# 0          0.000000  0.109790  0.108640  0.35185
# 1          0.214360  0.120020  0.093160  0.53565
# 2          0.007887  0.115930  0.019911  0.44885
# 3          0.000000  0.103650  0.272670  0.49335
# 4          0.000000  0.063542  0.175690  0.99797
# ...             ...       ...       ...      ...
# 42300      0.017391  0.676660  0.021975  0.56720
# 42301      0.002255  0.380950  0.559480  0.59617
# 42302      0.000004  0.481220  0.592490  0.56692
# 42303      0.000000  0.833210  0.169500  0.59818
# 42304      0.000200  0.469970  0.062932  0.56715
#
# [42305 rows x 10 columns]

# %%
# axes instance
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(serial_csv.energy, serial_csv.tempo, serial_csv.loudness, c=serial_csv.centroid, marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('energy')
ax.set_ylabel('tempo')
ax.set_zlabel('loudness')

# legend
plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)

# save
#plt.savefig("serial_results")

# %%
openmp_csv = pd.read_csv("results/OpenMPResults.csv")
openmp_csv
# Out:
#        centroid  danceability   energy  loudness  speechiness  acousticness  \
# 0             0       0.77246  0.32684   0.57118     0.425970      0.222670
# 1             0       0.75620  0.72593   0.73831     0.280840      0.262140
# 2             0       0.76596  0.41286   0.68933     0.071808      0.036537
# 3             0       0.79196  0.62691   0.71571     0.318750      0.017408
# 4             0       0.70853  0.49288   0.71571     0.061410      0.405870
# ...         ...           ...      ...       ...          ...           ...
# 42300         7       0.41705  0.96999   0.79291     0.035850      0.076517
# 42301         7       0.25994  0.92398   0.79178     0.196360      0.002509
# 42302         7       0.39647  0.79995   0.78351     0.055128      0.009220
# 42303         7       0.32712  0.87197   0.76688     0.027943      0.005738
# 42304         7       0.47340  0.99100   0.79507     0.235350      0.005606
#
#        instrumental  liveness   valence    tempo
# 0          0.000041  0.074696  0.424330  0.50666
# 1          0.000000  0.088918  0.340760  0.49957
# 2          0.000000  0.102630  0.198390  0.45587
# 3          0.000000  0.113890  0.291240  0.12035
# 4          0.000000  0.109790  0.108640  0.35185
# ...             ...       ...       ...      ...
# 42300      0.017391  0.676660  0.021975  0.56720
# 42301      0.002255  0.380950  0.559480  0.59617
# 42302      0.000004  0.481220  0.592490  0.56692
# 42303      0.000000  0.833210  0.169500  0.59818
# 42304      0.000200  0.469970  0.062932  0.56715
#
# [42305 rows x 10 columns]

# %%
# axes instance
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(openmp_csv.energy, openmp_csv.tempo, openmp_csv.loudness, c=openmp_csv.centroid, marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('energy')
ax.set_ylabel('tempo')
ax.set_zlabel('loudness')

# legend
plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)

# save
#plt.savefig("serial_results")

# %%
gpu = pd.read_csv("results/cudaResults.csv")
gpu
# Out:
#        centroid  danceability   energy  loudness  speechiness  acousticness  \
# 0             3       0.82988  0.81395   0.71204     0.430300      0.060525
# 1             0       0.70853  0.49288   0.71571     0.061410      0.405870
# 2             6       0.85047  0.89297   0.78274     0.042890      0.013967
# 3             6       0.44523  0.78095   0.78474     0.086971      0.023987
# 4             3       0.79413  0.62391   0.70371     0.292750      0.219630
# ...         ...           ...      ...       ...          ...           ...
# 42300         6       0.50157  0.69293   0.77274     0.008340      0.031882
# 42301         6       0.48965  0.76794   0.69675     0.027293      0.022772
# 42302         6       0.32062  0.82096   0.82879     0.030109      0.026315
# 42303         6       0.44631  0.92098   0.78291     0.017871      0.000557
# 42304         0       0.50265  0.94499   0.75318     0.042023      0.001912
#
#        instrumental  liveness   valence    tempo
# 0          0.013549  0.045943  0.382030  0.61001
# 1          0.000000  0.109790  0.108640  0.35185
# 2          0.000004  0.369690  0.021046  0.98620
# 3          0.000000  0.105700  0.161250  0.79459
# 4          0.000000  0.158910  0.590430  0.55458
# ...             ...       ...       ...      ...
# 42300      0.000349  0.112860  0.387190  0.56705
# 42301      0.000018  0.198810  0.375840  0.56653
# 42302      0.000245  0.382990  0.108640  0.59738
# 42303      0.029929  0.047887  0.484160  0.56723
# 42304      0.000055  0.412670  0.118950  0.59807
#
# [42305 rows x 10 columns]

# %%
# axes instance
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(gpu.energy, gpu.tempo, gpu.loudness, c=gpu.centroid, marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('energy')
ax.set_ylabel('tempo')
ax.set_zlabel('loudness')

# legend
plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)

# save
#plt.savefig("serial_results")

# %%
mpi = pd.read_csv("results/MPIResults.csv")
mpi
# Out:
#        centroid  danceability   energy  loudness  speechiness  acousticness  \
# 0             0       0.70853  0.49288   0.71571     0.061410      0.405870
# 1             0       0.71069  0.56789   0.60436     0.423810      0.045748
# 2             0       0.70744  0.66792   0.79975     0.123800      0.025707
# 3             0       0.68144  0.71093   0.76242     0.214770      0.040181
# 4             0       0.76812  0.75094   0.84679     0.189860      0.062145
# ...         ...           ...      ...       ...          ...           ...
# 42300         7       0.41705  0.96999   0.79291     0.035850      0.076517
# 42301         7       0.25994  0.92398   0.79178     0.196360      0.002509
# 42302         7       0.39647  0.79995   0.78351     0.055128      0.009220
# 42303         7       0.32712  0.87197   0.76688     0.027943      0.005738
# 42304         7       0.47340  0.99100   0.79507     0.235350      0.005606
#
#        instrumental  liveness   valence    tempo
# 0          0.000000  0.109790  0.108640  0.35185
# 1          0.214360  0.120020  0.093160  0.53565
# 2          0.007887  0.115930  0.019911  0.44885
# 3          0.000000  0.103650  0.272670  0.49335
# 4          0.000000  0.063542  0.175690  0.99797
# ...             ...       ...       ...      ...
# 42300      0.017391  0.676660  0.021975  0.56720
# 42301      0.002255  0.380950  0.559480  0.59617
# 42302      0.000004  0.481220  0.592490  0.56692
# 42303      0.000000  0.833210  0.169500  0.59818
# 42304      0.000200  0.469970  0.062932  0.56715
#
# [42305 rows x 10 columns]

# %%
# axes instance
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(mpi.energy, mpi.tempo, mpi.loudness, c=mpi.centroid, marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('energy')
ax.set_ylabel('tempo')
ax.set_zlabel('loudness')

# legend
plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)

# save
#plt.savefig("serial_results")

# %%
mpi_gpu = pd.read_csv("results/MPIandCudaResults.csv")
mpi_gpu
# Out:
#        centroid  danceability   energy  loudness  speechiness  acousticness  \
# 0             0       0.70853  0.49288   0.71571     0.061410      0.405870
# 1             0       0.71069  0.56789   0.60436     0.423810      0.045748
# 2             0       0.70744  0.66792   0.79975     0.123800      0.025707
# 3             0       0.68144  0.71093   0.76242     0.214770      0.040181
# 4             0       0.76812  0.75094   0.84679     0.189860      0.062145
# ...         ...           ...      ...       ...          ...           ...
# 42300         7       0.41705  0.96999   0.79291     0.035850      0.076517
# 42301         7       0.25994  0.92398   0.79178     0.196360      0.002509
# 42302         7       0.39647  0.79995   0.78351     0.055128      0.009220
# 42303         7       0.32712  0.87197   0.76688     0.027943      0.005738
# 42304         7       0.47340  0.99100   0.79507     0.235350      0.005606
#
#        instrumental  liveness   valence    tempo
# 0          0.000000  0.109790  0.108640  0.35185
# 1          0.214360  0.120020  0.093160  0.53565
# 2          0.007887  0.115930  0.019911  0.44885
# 3          0.000000  0.103650  0.272670  0.49335
# 4          0.000000  0.063542  0.175690  0.99797
# ...             ...       ...       ...      ...
# 42300      0.017391  0.676660  0.021975  0.56720
# 42301      0.002255  0.380950  0.559480  0.59617
# 42302      0.000004  0.481220  0.592490  0.56692
# 42303      0.000000  0.833210  0.169500  0.59818
# 42304      0.000200  0.469970  0.062932  0.56715
#
# [42305 rows x 10 columns]

# %%
# axes instance
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(mpi_gpu.energy, mpi_gpu.tempo, mpi_gpu.loudness, c=mpi_gpu.centroid, marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('energy')
ax.set_ylabel('tempo')
ax.set_zlabel('loudness')

# legend
plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)

# save
#plt.savefig("serial_results")
