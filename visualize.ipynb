# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap

# %%
serial_csv = pd.read_csv("results/serialResults.csv")
serial_csv
# Out:
#        centroid  danceability   energy  loudness  speechiness  \
# 0             0       0.85047  0.89297   0.78274     0.042890
# 1             0       0.44523  0.78095   0.78474     0.086971
# 2             0       0.76812  0.75094   0.84679     0.189860
# 3             0       0.89706  0.90698   0.62871     0.372900
# 4             0       0.72695  0.93198   0.81170     0.268930
# ...         ...           ...      ...       ...          ...
# 42300         3       0.60559  0.73694   0.73182     0.016029
# 42301         3       0.25019  0.70593   0.74149     0.026752
# 42302         3       0.59042  0.81696   0.67862     0.026102
# 42303         3       0.47882  0.71993   0.75179     0.018845
# 42304         3       0.55575  0.62491   0.80734     0.007040
#
#            acousticness  instrumental  liveness   valence    tempo
# 0              0.013967      0.000004  0.369690  0.021046  0.98620
# 1              0.023987      0.000000  0.105700  0.161250  0.79459
# ...

# %%
# axes instance
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(serial_csv.energy, serial_csv.tempo, serial_csv.loudness, c=serial_csv.centroid, marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('energy')
ax.set_ylabel('tempo')
ax.set_zlabel('loudness')

# legend
plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)

# save
#plt.savefig("serial_results")

# %%
openmp_csv = pd.read_csv("results/OpenMPResults.csv")
openmp_csv
# Out:
#        centroid  danceability   energy  loudness  speechiness  \
# 0             0       0.85047  0.89297   0.78274     0.042890
# 1             0       0.44523  0.78095   0.78474     0.086971
# 2             0       0.76812  0.75094   0.84679     0.189860
# 3             0       0.89706  0.90698   0.62871     0.372900
# 4             0       0.72695  0.93198   0.81170     0.268930
# ...         ...           ...      ...       ...          ...
# 42300         3       0.60559  0.73694   0.73182     0.016029
# 42301         3       0.25019  0.70593   0.74149     0.026752
# 42302         3       0.59042  0.81696   0.67862     0.026102
# 42303         3       0.47882  0.71993   0.75179     0.018845
# 42304         3       0.55575  0.62491   0.80734     0.007040
#
#            acousticness  instrumental  liveness   valence    tempo
# 0              0.013967      0.000004  0.369690  0.021046  0.98620
# 1              0.023987      0.000000  0.105700  0.161250  0.79459
# ...

# %%
# axes instance
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(openmp_csv.energy, openmp_csv.tempo, openmp_csv.loudness, c=openmp_csv.centroid, marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('energy')
ax.set_ylabel('tempo')
ax.set_zlabel('loudness')

# legend
plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)

# save
#plt.savefig("serial_results")

# %%
gpu = pd.read_csv("results/cudaResults.csv")
gpu
# Out:
#        centroid  danceability   energy  loudness  speechiness  acousticness  \
# 0             1       0.82988  0.81395   0.71204     0.430300      0.060525
# 1             3       0.70853  0.49288   0.71571     0.061410      0.405870
# 2             0       0.85047  0.89297   0.78274     0.042890      0.013967
# 3             0       0.44523  0.78095   0.78474     0.086971      0.023987
# 4             1       0.79413  0.62391   0.70371     0.292750      0.219630
# ...         ...           ...      ...       ...          ...           ...
# 42300         0       0.50157  0.69293   0.77274     0.008340      0.031882
# 42301         0       0.48965  0.76794   0.69675     0.027293      0.022772
# 42302         0       0.32062  0.82096   0.82879     0.030109      0.026315
# 42303         0       0.44631  0.92098   0.78291     0.017871      0.000557
# 42304         0       0.50265  0.94499   0.75318     0.042023      0.001912
#
#        instrumental  liveness   valence    tempo
# ...

# %%
# axes instance
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(gpu.energy, gpu.tempo, gpu.loudness, c=gpu.centroid, marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('energy')
ax.set_ylabel('tempo')
ax.set_zlabel('loudness')

# legend
plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)

# save
#plt.savefig("serial_results")

# %%
mpi = pd.read_csv("results/MPIResults.csv")
mpi
# Out:
#        centroid  danceability   energy  loudness  speechiness  \
# 0             0       0.50265  0.94499   0.75318     0.042023
# 1             0       0.85047  0.89297   0.78274     0.042890
# 2             0       0.44523  0.78095   0.78474     0.086971
# 3             0       0.76812  0.75094   0.84679     0.189860
# 4             0       0.89706  0.90698   0.62871     0.372900
# ...         ...           ...      ...       ...          ...
# 42300         3       0.60559  0.73694   0.73182     0.016029
# 42301         3       0.25019  0.70593   0.74149     0.026752
# 42302         3       0.59042  0.81696   0.67862     0.026102
# 42303         3       0.47882  0.71993   0.75179     0.018845
# 42304         3       0.55575  0.62491   0.80734     0.007040
#
#            acousticness  instrumental  liveness   valence    tempo
# 0              0.001912      0.000055  0.412670  0.118950  0.59807
# 1              0.013967      0.000004  0.369690  0.021046  0.98620
# ...

# %%
# axes instance
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(mpi.energy, mpi.tempo, mpi.loudness, c=mpi.centroid, marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('energy')
ax.set_ylabel('tempo')
ax.set_zlabel('loudness')

# legend
plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)

# save
#plt.savefig("serial_results")

# %%
mpi_gpu = pd.read_csv("results/MPIAndCudaResults.csv")
mpi_gpu
# Out:
#        centroid  danceability   energy  loudness  speechiness  \
# 0             0       0.50265  0.94499   0.75318     0.042023
# 1             0       0.85047  0.89297   0.78274     0.042890
# 2             0       0.44523  0.78095   0.78474     0.086971
# 3             0       0.76812  0.75094   0.84679     0.189860
# 4             0       0.89706  0.90698   0.62871     0.372900
# ...         ...           ...      ...       ...          ...
# 42300         3       0.60559  0.73694   0.73182     0.016029
# 42301         3       0.25019  0.70593   0.74149     0.026752
# 42302         3       0.59042  0.81696   0.67862     0.026102
# 42303         3       0.47882  0.71993   0.75179     0.018845
# 42304         3       0.55575  0.62491   0.80734     0.007040
#
#            acousticness  instrumental  liveness   valence    tempo
# 0              0.001912      0.000055  0.412670  0.118950  0.59807
# 1              0.013967      0.000004  0.369690  0.021046  0.98620
# ...

# %%
# axes instance
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(mpi_gpu.energy, mpi_gpu.tempo, mpi_gpu.loudness, c=mpi_gpu.centroid, marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('energy')
ax.set_ylabel('tempo')
ax.set_zlabel('loudness')

# legend
plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)

# save
#plt.savefig("serial_results")
